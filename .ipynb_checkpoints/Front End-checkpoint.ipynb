# %%
from flask import Flask
from flask import render_template, request

# %%
#from app import app
app = Flask(__name__)

@app.route('/home')

def index():
    
    return render_template('index.html',title = 'Home')
@app.route('/developthon')

def developthon():
    return render_template('support.html', title = 'Developthon')

@app.route('/result1',methods = ['POST', 'GET'])
def result1():
    if request.method == 'POST':
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
    
    result = request.form
    return details

@app.route('/result3', methods = ['POST', 'GET'])

def result3():
    if request.method == "POST":
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        def remove_emp(id):
            name = details[id][0]
            details[id][0] = "NULL"
            conn = sqlite3.connect('present.db')
            cur = conn.cursor()
            cur.execute('INSERT INTO past (id,name,position) VALUES (?,?,?)',(id,name,details[id][1],))
            #sqlstr = 'UPDATE present SET emp_name = "NULL" WHERE emp_id = {}'.format(id)
            cur.execute('UPDATE present SET emp_name = "NULL" WHERE emp_id = ?',(id,))
            conn.commit()
            cur.close()
        rem = input("Enter the employee id to be removed :")
        
        print_res = {"Employee Removed":remove_emp(rem)}
    return print_res
        
@app.route('/result4', methods = ['POST', 'GET'])
    
def result4():
    if request.method == "POST":
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        def adj_senior(id):
            senior = details[id][2][0]
            depth = 1
            while True:
                if details[senior][0]=="NULL":
                    senior = details[senior][2][0]
                    depth += 1
                else:
                    return senior,depth
        
        find = input("Enter the employee id to get the immediate senior : ")
        #print(adj_senior(find))
        print_res = {"Reporting Senior": adj_senior(find)}
    return print_res

@app.route('/result5', methods = ['POST', 'GET'])

def result5():
    if request.method == 'POST':
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        count = 0
        for i in details:
            if details[i][0]=="NULL":
                count += 1
                print(i,details[i][1])
        print("Number of positions empty",count)
        print_res = { 'Number of Positions Empty' : count }
    return print_res

    
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Feb/2020 09:27:16] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:16] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:19] "GET /developthon HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /css/style.css HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /css/coin-slider.css HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /js/cufon-yui.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /js/cufon-ubuntu.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /js/jquery-1.4.2.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /js/script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /js/coin-slider.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /images/slide1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /images/slide2.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /images/slide3.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /images/gal1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /images/gal2.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /images/gal3.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /images/gal4.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /images/gal5.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:20] "GET /images/gal6.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:26] "POST /result1 HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 09:27:27] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 09:27:31] "POST /result2 HTTP/1.1" 404 -
# Enter the employee id to be removed :05
# [2020-02-02 09:27:58,823] ERROR in app: Exception on /result3 [POST]
# Traceback (most recent call last):
#   File "C:\Users\aksha\Anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\aksha\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\aksha\Anaconda3\lib\site-packages\flask\app.py", line 1967, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\aksha\Anaconda3\lib\site-packages\flask\app.py", line 2130, in make_response
#     " {rv.__class__.__name__}.".format(rv=rv)
# TypeError: The view function did not return a valid response. The return type must be a string, dict, tuple, Response instance, or WSGI callable, but it was a set.
# 127.0.0.1 - - [02/Feb/2020 09:27:58] "POST /result3 HTTP/1.1" 500 -
