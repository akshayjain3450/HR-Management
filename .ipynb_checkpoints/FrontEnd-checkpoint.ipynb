# %%
from flask import Flask
from flask import render_template, request

# %%
#from app import app
app = Flask(__name__)

@app.route('/home')

def index():
    
    return render_template('index.html',title = 'Home')
@app.route('/developthon')

def developthon():
    return render_template('support.html', title = 'Developthon')

@app.route('/result1',methods = ['POST', 'GET'])
def result1():
    if request.method == 'POST':
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
    
    result = request.form
    return details

@app.route('/result2',methods = ['POST', 'GET'])
def result2():
    if request.method == 'POST':
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        def add_emp(id):
            if details[id][0] == "NULL":
                name = input("Input name : ")
                details[id][0] = name
                conn = sqlite3.connect('present.db')
                cur = conn.cursor()
                cur.execute('UPDATE present SET emp_name = ? WHERE emp_id = ?',(name,id,))
                conn.commit()
                cur.close()
            else:
                print("Position not empty!")
        add = input("Enter the employee id where name to be added :")
        
        print_res = {"Employee Added":add_emp(add)}
    #result = request.form
    return print_res

@app.route('/result3', methods = ['POST', 'GET'])

def result3():
    if request.method == "POST":
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        def remove_emp(id):
            name = details[id][0]
            details[id][0] = "NULL"
            conn = sqlite3.connect('present.db')
            cur = conn.cursor()
            cur.execute('INSERT INTO past (id,name,position) VALUES (?,?,?)',(id,name,details[id][1],))
            #sqlstr = 'UPDATE present SET emp_name = "NULL" WHERE emp_id = {}'.format(id)
            cur.execute('UPDATE present SET emp_name = "NULL" WHERE emp_id = ?',(id,))
            conn.commit()
            cur.close()
        rem = input("Enter the employee id to be removed :")
        
        print_res = {"Employee Removed":remove_emp(rem)}
    return print_res
        
@app.route('/result4', methods = ['POST', 'GET'])
    
def result4():
    if request.method == "POST":
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        def adj_senior(id):
            senior = details[id][2][0]
            depth = 1
            while True:
                if details[senior][0]=="NULL":
                    senior = details[senior][2][0]
                    depth += 1
                else:
                    return senior,depth
        
        find = input("Enter the employee id to get the immediate senior : ")
        #print(adj_senior(find))
        print_res = {"Reporting Senior": adj_senior(find)}
    return print_res

@app.route('/result5', methods = ['POST', 'GET'])

def result5():
    if request.method == 'POST':
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        count = 0
        for i in details:
            if details[i][0]=="NULL":
                count += 1
                print(i,details[i][1])
        print("Number of positions empty",count)
        print_res = { 'Number of Positions Empty' : count }
    return print_res

@app.route('/result6', methods = ['POST', 'GET'])

def result6():
    if request.method == 'POST':
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        # add new person in an in-between level
        def addNew():

            while True:
                id = input("Enter new id : ")
                if id not in details:
                    break
                else:
                    print("This id already exists.")

            name = input("Enter name : ")
            pos = input("Enter position : ")
            upper = input("Enter upper id : ")
            lower = input("Enter lower id : ")

            details[id]=[]
            details[id].append(name)
            details[id].append(pos)
            details[id].append(upper)
            details[id].append(lower)

            conn = sqlite3.connect('present.db')
            cur = conn.cursor()
            cur.execute('INSERT INTO present (emp_id, emp_name, emp_position, upper, lower) VALUES (?,?,?,?,?)',(id,name,pos,upper,lower,))

            # upper list of lower
            uLow = details[str(lower)][2]
            ul = ""   
            for x in uLow: 
                if x == upper:
                    ul += id
                else:
                    ul += x 
                ul += ' '
            # lower list of upper       
            lUp = details[str(upper)][3]
            lu = ""   
            for x in lUp: 
                if x == lower:
                    lu += id
                else:
                    lu += x 
                lu += ' '

            details[lower][2] = ul.split(" ")
            details[upper][3] = lu.split(" ")
            cur.execute('UPDATE present SET upper = ? where emp_id = ?',(ul,lower,))
            cur.execute('UPDATE present SET lower = ? where emp_id = ?',(lu,upper,))
            print(ul)
            conn.commit()
            cur.close()

        #addNew()
        print_res = {"Depth ": addNew()}
    return print_res


@app.route('/result7', methods = ['POST', 'GET'])

def result7():
    if request.method == 'POST':
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        def depth(id):
            count = 0
            # details[id][2][0]
            while True:
                id = details[id][2][0]
                if id == 'NULL':
                    break
                if details[id][0] != 'NULL':
                    count += 1
            return count
    
        id = input("Enter id : ")
        #print('Depth is',depth(id))
        print_res = {"Depth ": depth(id)}
    return print_res

@app.route('/result8', methods = ['POST', 'GET'])

def result8():
    if request.method == 'POST':
        import sqlite3
        conn = sqlite3.connect('present.db')
        cur = conn.cursor()

        sqlstr = 'SELECT emp_id, emp_name, emp_position, upper, lower FROM present'
        details = {}
        for row in cur.execute(sqlstr):
            emp_id = row[0]
            emp_name = row[1]
            emp_pos = row[2]
            if row[3] is not "NULL":
                upper = row[3].split(" ")
            if row[4] is not "NULL":
                lower = row[4].split(" ")
            details[emp_id]=[]
            details[emp_id].append(emp_name)
            details[emp_id].append(emp_pos)
            details[emp_id].append(upper)
            details[emp_id].append(lower)

        cur.close()
        def depth(id):
            count = 0
            # details[id][2][0]
            while True:
                id = details[id][2][0]
                if id == 'NULL':
                    break
                if details[id][0] != 'NULL':
                    count += 1
            return count        
        def diff(small,big):
            b = depth(big)
            s = depth(small)
            return s-b

        small = input("Input smaller level id : ")
        big = input("Input bigger level id : ")
        print_res = {"Depth Difference": diff(small,big)}
    return print_res
    
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Feb/2020 12:32:08] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /developthon HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /css/style.css HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /css/coin-slider.css HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /js/cufon-yui.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /js/cufon-ubuntu.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /js/jquery-1.4.2.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /js/script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /js/coin-slider.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /images/slide1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /images/slide2.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /images/slide3.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /images/gal1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /images/gal2.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /images/gal3.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /images/gal4.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /images/gal5.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Feb/2020 12:32:14] "GET /images/gal6.jpg HTTP/1.1" 404 -
